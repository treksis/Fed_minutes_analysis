# %%
import os
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import nltk

# %%
def file_opener(json_file):
    file_to_open = data_folder / json_file
    f = open(file_to_open)
    data = json.load(f)

    data.keys()

    a = data['Staff Review of the Economic Situation']
    b = data['Staff Review of the Financial Situation']
    c = data['Staff Economic Outlook']
    d = data["Participants' Views on Current Economic Conditions and the Economic Outlook"]
    #e = data['Committee Policy Action']

    a.extend(b+c+d)
    
    total = ''.join(a)

    return a, b, c, d, total

# %%
def bigrams(text):
    words = nltk.word_tokenize(text)
    stopwords = nltk.corpus.stopwords.words("english")
    stopwords.extend(["governors", "board", "federal", "reserve"])
    words =[word.lower() for word in words if word.isalpha() if word not in stopwords]
    bigrams = nltk.collocations.BigramAssocMeasures()
    bigramFinder = nltk.collocations.BigramCollocationFinder.from_words(words)
    bigram_freq = bigramFinder.ngram_fd.items()
    bigramFreqTable = pd.DataFrame(list(bigram_freq), columns=['bigram','freq']).sort_values(by='freq', ascending=False)
    
    return bigramFreqTable

# %%
def bigrams_process():
    staff_review_econ = ''.join(a)
    staff_review_financial = ''.join(b)
    staff_econ_outlook = ''.join(c)
    participants_views = ''.join(d)
    #policy_action = ''.join(e)
    sample = ''.join(total)

    df_staff_review_econ = bigrams(staff_review_econ)
    df_staff_review_financial = bigrams(staff_review_financial)
    df_staff_econ_outlook = bigrams(staff_econ_outlook)
    df_participants_views = bigrams(participants_views)
    #df_policy_action = bigrams(policy_action)
    df_sample = bigrams(sample)

    print(df_sample.head())

    return df_staff_review_econ, df_staff_review_financial, df_staff_econ_outlook, df_participants_views, df_sample

# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

def bigrams_plot():
    df = df_sample.head(20).reset_index(drop=True)
    #print(df)
    ax = df.plot.bar(x='bigram', y='freq', rot=0, figsize=(20,10))
    plt.xticks(rotation=45, ha='right')

    # initialize a figure
    fig=plt.figure(figsize=(18, 6))
    plt.subplots_adjust(hspace = 2)
    
    # Do a 2x2 chart
    ax1 = fig.add_subplot(221)
    df_staff_review_econ.head(8).plot(x='bigram', y='freq', kind='bar', ax=ax1, legend=False).set_title('staff review econ')
    plt.xticks(rotation=45, ha='right')

    ax2 = fig.add_subplot(222)
    df_staff_review_financial.head(8).plot(x='bigram', y='freq', kind='bar', ax=ax2, legend=False, color="orange").set_title('staff review finance')
    plt.xticks(rotation=45, ha='right')

    ax3 = fig.add_subplot(223)
    df_staff_econ_outlook.head(8).plot(x='bigram', y='freq', kind='bar', ax=ax3, legend=False, color="green").set_title('staff econ outlook')
    plt.xticks(rotation=45, ha='right')

    ax4 = fig.add_subplot(224)
    df_participants_views.head(8).plot(x='bigram', y='freq', kind='bar', ax=ax4, legend=False, color="grey").set_title('participants view')
    plt.xticks(rotation=45, ha='right')

# %%
from pathlib import Path
import json

path_to_json = r'C:\Users\Howoo\Data_analysis\get_data\data'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]
print(json_files)

for i in json_files:

    data_folder = Path(r'C:\Users\Howoo\Data_analysis\get_data\data')
    file_to_open = data_folder / i

    f = open(file_to_open)
    data = json.load(f)

    a, b, c, d, total = file_opener(file_to_open)

    df_staff_review_econ, df_staff_review_financial, df_staff_econ_outlook, df_participants_views, df_sample = bigrams_process()
    #bigrams_plot()
# Out:
# ['20160316.htm.json', '20160427.htm.json', '20160615.htm.json', '20160727.htm.json', '20160921.htm.json', '20161102.htm.json', '20161214.htm.json', '20170201.htm.json', '20170315.htm.json', '20170503.htm.json', '20170614.htm.json', '20170726.htm.json', '20170920.htm.json', '20171101.htm.json', '20171213.htm.json', '20180131.htm.json', '20180321.htm.json', '20180502.htm.json', '20180613.htm.json', '20180801.htm.json', '20180926.htm.json', '20181108.htm.json', '20181219.htm.json', '20190130.htm.json', '20190320.htm.json', '20190501.htm.json', '20190619.htm.json', '20190731.htm.json', '20190918.htm.json', '20191030.htm.json', '20191211.htm.json', '20200129.htm.json', '20200315.htm.json', '20200429.htm.json', '20200610.htm.json', '20200729.htm.json', '20200916.htm.json', '20201105.htm.json', '20201216.htm.json', '20210127.htm.json', '20210317.htm.json', '20210428.htm.json', '20210616.htm.json', '20210728.htm.json']
#                  bigram  freq
# 791       (funds, rate)    19
# 47    (little, changed)    12
# 10      (labor, market)    11
# 40     (energy, prices)    10
# 673  (monetary, policy)     9
#                    bigram  freq
# 15       (first, quarter)    22
# 729         (funds, rate)    19
# 11        (labor, market)    15
# 39       (energy, prices)    10
# 12   (market, conditions)     9
#                      bigram  freq
# 12          (labor, market)    21
# 725           (funds, rate)    18
# 26         (first, quarter)    15
# 697  (intermeeting, period)    11
# 40         (energy, prices)    10
#                      bigram  freq
# 10          (labor, market)    19
# 640           (funds, rate)    18
# 23        (second, quarter)    13
# 37         (energy, prices)    11
# 857  (treasury, securities)    11
#                    bigram  freq
# 59   (unemployment, rate)    13
# 20       (third, quarter)    12
# 10       (recent, months)    11
# 844    (monetary, policy)    10
# 581    (economic, growth)     9
#                    bigram  freq
# 667         (funds, rate)    20
# 54      (little, changed)    16
# 18       (third, quarter)    15
# 23        (labor, market)    12
# 68   (unemployment, rate)     9
#                    bigram  freq
# 627         (funds, rate)    19
# 21        (labor, market)    17
# 637    (monetary, policy)    14
# 625       (target, range)    10
# 22   (market, conditions)    10
#                 bigram  freq
# 662      (funds, rate)    20
# 18   (fourth, quarter)    17
# 22     (labor, market)    13
# 597  (little, changed)    12
# 660    (target, range)    11
#                  bigram  freq
# 658       (funds, rate)    19
# 50    (little, changed)    13
# 10      (labor, market)    13
# 27    (fourth, quarter)    12
# 682  (monetary, policy)    12
#                    bigram  freq
# 21       (first, quarter)    24
# 736         (funds, rate)    15
# 10        (labor, market)    11
# 447           (real, gdp)    10
# 675  (market, conditions)     8
#                   bigram  freq
# 28      (first, quarter)    17
# 740        (funds, rate)    15
# 10       (labor, market)    11
# 471          (real, gdp)    10
# 656  (economic, outlook)     9
#                    bigram  freq
# 25      (second, quarter)    14
# 638         (funds, rate)    14
# 10        (labor, market)    10
# 78      (little, changed)     8
# 11   (market, conditions)     8
#                      bigram  freq
# 760           (funds, rate)    16
# 15           (july, august)    11
# 708  (intermeeting, period)    10
# 10          (labor, market)    10
# 49     (economic, activity)     9
#                      bigram  freq
# 662           (funds, rate)    17
# 24         (third, quarter)    15
# 10          (labor, market)    11
# 507    (economic, activity)    10
# 578  (intermeeting, period)     8
#                      bigram  freq
# 602           (funds, rate)    14
# 49        (little, changed)    13
# 10          (labor, market)    11
# 503    (economic, activity)     9
# 544  (intermeeting, period)     9
#                    bigram  freq
# 599         (funds, rate)    18
# 10        (labor, market)    12
# 24      (fourth, quarter)    12
# 597       (target, range)    11
# 445  (economic, activity)    11
#                    bigram  freq
# 690         (funds, rate)    16
# 10        (labor, market)    11
# 525  (economic, activity)    10
# 681   (economic, outlook)     9
# 90       (recent, months)     9
#                      bigram  freq
# 15         (first, quarter)    22
# 655           (funds, rate)    14
# 588  (intermeeting, period)    13
# 10          (labor, market)    11
# 478             (real, gdp)     8
#                 bigram  freq
# 46   (little, changed)    12
# 762      (funds, rate)    11
# 10     (labor, market)    11
# 419        (real, gdp)     9
# 760    (target, range)     8
#                      bigram  freq
# 220       (second, quarter)    14
# 47        (little, changed)    13
# 10          (labor, market)    12
# 589           (funds, rate)    10
# 554  (intermeeting, period)    10
#                    bigram  freq
# 711         (funds, rate)    10
# 10        (labor, market)    10
# 70      (little, changed)     9
# 709       (target, range)     9
# 83   (unemployment, rate)     8
#                    bigram  freq
# 25       (third, quarter)    12
# 10        (labor, market)    10
# 689         (funds, rate)    10
# 687       (target, range)     9
# 62   (unemployment, rate)     8
#                    bigram  freq
# 10        (labor, market)    11
# 637         (funds, rate)     9
# 11   (market, conditions)     8
# 557  (economic, activity)     7
# 52   (unemployment, rate)     7
#                 bigram  freq
# 22   (fourth, quarter)    18
# 728      (funds, rate)    12
# 10     (labor, market)    10
# 738    (target, range)    10
# 24        (last, year)     9
#                    bigram  freq
# 10        (labor, market)    11
# 27       (first, quarter)    11
# 751         (funds, rate)    10
# 622  (economic, activity)     9
# 91   (unemployment, rate)     9
#                    bigram  freq
# 23       (first, quarter)    21
# 731         (funds, rate)    11
# 10        (labor, market)    11
# 754       (target, range)     9
# 68   (unemployment, rate)     8
#                   bigram  freq
# 766        (funds, rate)    10
# 61          (april, may)     9
# 10       (labor, market)     9
# 682  (economic, outlook)     8
# 764      (target, range)     8
#                      bigram  freq
# 679           (funds, rate)    15
# 23        (second, quarter)    15
# 736         (target, range)    12
# 649  (intermeeting, period)    11
# 737          (range, funds)    10
#                      bigram  freq
# 776           (funds, rate)    14
# 691  (intermeeting, period)    12
# 843         (target, range)    10
# 50           (july, august)    10
# 40    (measures, inflation)     8
#                    bigram  freq
# 23       (third, quarter)    15
# 741         (funds, rate)    12
# 739       (target, range)    11
# 740        (range, funds)     9
# 85   (unemployment, rate)     8
#                    bigram  freq
# 717         (funds, rate)     9
# 715       (target, range)     9
# 94   (unemployment, rate)     8
# 378         (shy, though)     8
# 377             (al, shy)     8
#                      bigram  freq
# 23        (fourth, quarter)    15
# 731           (funds, rate)    10
# 641  (intermeeting, period)    10
# 729         (target, range)     8
# 78     (unemployment, rate)     8
#                        bigram  freq
# 4        (economic, activity)    25
# 567    (intermeeting, period)    18
# 1     (coronavirus, outbreak)    16
# 1510    (participants, noted)    13
# 661           (target, range)    12
#                       bigram  freq
# 153       (federal, reserve)    20
# 5    (coronavirus, outbreak)    16
# 628   (intermeeting, period)    13
# 39          (first, quarter)    11
# 14      (economic, activity)    10
#                      bigram  freq
# 224      (federal, reserve)    16
# 13     (economic, activity)    11
# 604  (intermeeting, period)    11
# 35        (second, quarter)     9
# 963      (monetary, policy)     8
#                      bigram  freq
# 14     (economic, activity)    12
# 697  (intermeeting, period)    11
# 198      (federal, reserve)    11
# 49        (second, quarter)     8
# 16         (united, states)     7
#                      bigram  freq
# 635  (intermeeting, period)    13
# 251      (monetary, policy)    13
# 37           (july, august)    10
# 173      (federal, reserve)    10
# 65                (al, shy)     9
#                       bigram  freq
# 660   (intermeeting, period)    16
# 1727      (monetary, policy)    10
# 111        (little, changed)     9
# 233       (federal, reserve)     9
# 33          (third, quarter)     8
#                      bigram  freq
# 136      (federal, reserve)    11
# 1384     (monetary, policy)    10
# 48      (october, november)     9
# 1515  (maximum, employment)     8
# 1579     (stance, monetary)     7
#                       bigram  freq
# 610   (intermeeting, period)    13
# 28         (fourth, quarter)     9
# 1668      (monetary, policy)     9
# 135       (federal, reserve)     8
# 693        (little, changed)     8
#                       bigram  freq
# 820   (intermeeting, period)    12
# 36              (last, year)    12
# 148       (federal, reserve)    10
# 1535      (monetary, policy)     9
# 55       (january, february)     9
#                       bigram  freq
# 30          (first, quarter)    13
# 621        (little, changed)    11
# 591   (intermeeting, period)     9
# 1371      (monetary, policy)     9
# 152       (federal, reserve)     8
#                          bigram  freq
# 751          (monetary, policy)    11
# 735      (intermeeting, period)    10
# 303   (inflation, expectations)     9
# 2069    (several, participants)     9
# 322           (little, changed)     8
#                       bigram  freq
# 17         (second, quarter)    14
# 910       (asset, purchases)    13
# 25           (labor, market)    12
# 587   (intermeeting, period)    11
# 1737   (participants, noted)    11
